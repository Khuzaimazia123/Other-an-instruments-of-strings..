# %%
bird = "crow"
result= bird.capitalize()
print (result)

word = ["Domestic","pet"]
Result=" ".join (word)#add space between ""
print (Result)

text="I like cats"
new_text =text.replace("cats","dogs")
print (new_text)

message= ("I like Pakistani food but I don't like foreign food")
print ("Pakistani" in message)
print ("foreign" not in message)

Message= ("I like to travel")
result=Message.split()
print (result)
# Out:
# Crow
# Domestic pet
# I like dogs
# True
# False
# ['I', 'like', 'to', 'travel']
